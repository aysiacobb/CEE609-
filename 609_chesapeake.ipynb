# %% [markdown]
# <a href="https://colab.research.google.com/github/aysiacobb/CEE609_Project_Cobb/blob/main/609_chesapeake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Chespeake Bay Project Code **

# %%
# Packages
import pandas as pd

# %%
# Data downloaded directly from laptop
monitor_event = pd.read_csv('MonitorEvent.csv')

station = pd.read_csv('Station.csv')

water_quality = pd.read_csv('WaterQuality.csv', low_memory=False)

# %%
# Checking na values in water quality df
combined_water_quality.isna().sum()
# Out:
# CBSeg2003                  0
# EventId                    0
# Cruise                  4034
# Program                    0
# Project                    0
# Agency                     0
# Source                     0
# Station                    0
# SampleDate                 0
# SampleTime                 0
# TotalDepth                 0
# UpperPycnocline        18919
# LowerPycnocline        18919
# Depth                      0
# Layer                      0
# SampleType                 0
# SampleReplicateType        0
# Parameter                  0
# Qualifier              40621
# MeasureValue              48
# Unit                       0
# Method                     0
# Lab                    31875
# Problem                40472
# PrecisionPC            40804
# BiasPC                 40804
# Details                40215
# Latitude                   0
# Longitude                  0
# TierLevel                  0
# geometry                   0
# dtype: int64

# %%
water_quality.head()
# Out:
#   CBSeg2003  EventId  Cruise Program Project Agency Source Station SampleDate  \
# 0    CB1TF   36911.0  BAY161    TWQM    MAIN  MDDNR  MDDNR   CB1.1    6/24/92
# 1    CB1TF   36910.0  BAY161    TWQM    MAIN  MDDNR  MDDNR   CB2.1    6/24/92
# 2    CB1TF   36910.0  BAY161    TWQM    MAIN  MDDNR  MDDNR   CB2.1    6/24/92
# 3    CB1TF   36911.0  BAY161    TWQM    MAIN  MDDNR  MDDNR   CB1.1    6/24/92
# 4    CB1TF   37095.0  BAY162    TWQM    MAIN  MDDNR  MDDNR   CB2.1     7/8/92
#
#   SampleTime  ...  Unit  Method    Lab  Problem PrecisionPC BiasPC Details  \
# 0    9:55:00  ...  UG/L    L01   MDHMH      NaN         NaN    NaN     NaN
# 1    9:20:00  ...  UG/L    L01   MDHMH      NaN         NaN    NaN     NaN
# 2    9:20:00  ...  UG/L    L01   MDHMH      NaN         NaN    NaN     NaN
# 3    9:55:00  ...  UG/L    L01   MDHMH      NaN         NaN    NaN     NaN
# 4    9:35:00  ...  UG/L    L01   MDHMH      NaN         NaN    NaN     NaN
#
#    Latitude Longitude  TierLevel
# 0  39.54794 -76.08481         T3
# 1  39.44149 -76.02599         T3
# 2  39.44149 -76.02599         T3
# 3  39.54794 -76.08481         T3
# 4  39.44149 -76.02599         T3
#
# [5 rows x 30 columns]

# %%
# Convert the 'SampleDate' column to datetime format
water_quality['SampleDate'] = pd.to_datetime(water_quality['SampleDate'], format='%m/%d/%y')

# Filter data from the year 2021
water_quality_2021 = water_quality[water_quality['SampleDate'].dt.year == 2021]

# Display the filtered 2021 data
print(water_quality_2021)
# Out:
#        CBSeg2003   EventId  Cruise Program Project Agency Source Station  \
# 665       CB1TF   588081.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB1.1
# 666       CB1TF   588082.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# 667       CB1TF   588081.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB1.1
# 668       CB1TF   588082.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# 669       CB1TF   588060.0  BAY789    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# ...          ...       ...     ...     ...     ...    ...    ...     ...
# 715977    CB8PH   487639.0  BAY785    TWQM    MAIN  VADEQ    ODU   CB8.1
# 715978    CB8PH   487639.0  BAY785    TWQM    MAIN  VADEQ    ODU   CB8.1
# 715979    CB8PH   487635.0  BAY785    TWQM    MAIN  VADEQ    ODU   CB7.4
# 715980    CB8PH   487635.0  BAY785    TWQM    MAIN  VADEQ    ODU   CB7.4
# 715981    CB8PH   487641.0  BAY785    TWQM    MAIN  VADEQ    ODU  CB8.1E
#
#        SampleDate SampleTime  ...   Unit  Method  Lab  Problem PrecisionPC  \
# 665    2021-02-10   11:17:00  ...   UG/L    L01   CBL      NaN         NaN
# 666    2021-02-10   10:37:00  ...   UG/L    L01   CBL      NaN         NaN
# 667    2021-02-10   11:17:00  ...   UG/L    L01   CBL      NaN         NaN
# 668    2021-02-10   10:37:00  ...   UG/L    L01   CBL      NaN         NaN
# 669    2021-03-18   14:39:00  ...   UG/L    L01   CBL      NaN         NaN
# ...           ...        ...  ...    ...     ...  ...      ...         ...
# 715977 2021-01-25   12:49:00  ...  DEG C    F01   NaN      NaN         NaN
# 715978 2021-01-25   12:49:00  ...  DEG C    F01   NaN      NaN         NaN
# 715979 2021-01-19    8:06:00  ...  DEG C    F01   NaN      NaN         NaN
# 715980 2021-01-19    8:06:00  ...  DEG C    F01   NaN      NaN         NaN
# 715981 2021-01-19    7:29:00  ...  DEG C    F01   NaN      NaN         NaN
#
#        BiasPC Details  Latitude Longitude  TierLevel
# 665       NaN     NaN  39.54794 -76.08481         T3
# 666       NaN     NaN  39.44149 -76.02599         T3
# 667       NaN     NaN  39.54794 -76.08481         T3
# 668       NaN     NaN  39.44149 -76.02599         T3
# 669       NaN     NaN  39.44149 -76.02599         T3
# ...       ...     ...       ...       ...        ...
# 715977    NaN     NaN  36.99542 -76.16772         T3
# 715978    NaN     NaN  36.99542 -76.16772         T3
# 715979    NaN     NaN  36.99570 -76.02048         T3
# 715980    NaN     NaN  36.99570 -76.02048         T3
# 715981    NaN     NaN  36.94737 -76.03494         T3
#
# [20869 rows x 30 columns]

# %%
# Filter data from the year 2022
water_quality_2022 = water_quality[water_quality['SampleDate'].dt.year == 2022]

# Display the filtered 2022 data
print(water_quality_2022)
# Out:
#        CBSeg2003   EventId  Cruise Program Project Agency Source Station  \
# 778       CB1TF   611565.0  BAY810    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# 779       CB1TF   611566.0  BAY810    TWQM    MAIN  MDDNR  MDDNR   CB1.1
# 780       CB1TF   611565.0  BAY810    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# 781       CB1TF   611566.0  BAY810    TWQM    MAIN  MDDNR  MDDNR   CB1.1
# 782       CB1TF   611582.0  BAY812    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# ...          ...       ...     ...     ...     ...    ...    ...     ...
# 706220    CB8PH   608326.0  BAY819    TWQM    MAIN  VADEQ    ODU   CB7.4
# 706221    CB8PH   608326.0  BAY819    TWQM    MAIN  VADEQ    ODU   CB7.4
# 706222    CB8PH   608335.0  BAY819    TWQM    MAIN  VADEQ    ODU  CB8.1E
# 706223    CB8PH   608332.0  BAY819    TWQM    MAIN  VADEQ    ODU   CB8.1
# 706224    CB8PH   608326.0  BAY819    TWQM    MAIN  VADEQ    ODU   CB7.4
#
#        SampleDate SampleTime  ...   Unit  Method  Lab  Problem PrecisionPC  \
# 778    2022-02-09   10:52:00  ...   UG/L    L01   CBL      NaN         NaN
# 779    2022-02-09   11:30:00  ...   UG/L    L01   CBL      NaN         NaN
# 780    2022-02-09   10:52:00  ...   UG/L    L01   CBL      NaN         NaN
# 781    2022-02-09   11:30:00  ...   UG/L    L01   CBL      NaN         NaN
# 782    2022-03-16   10:48:00  ...   UG/L    L01   CBL      NaN         NaN
# ...           ...        ...  ...    ...     ...  ...      ...         ...
# 706220 2022-06-27   13:39:00  ...  DEG C    F01   NaN      NaN         NaN
# 706221 2022-06-27   13:39:00  ...  DEG C    F01   NaN      NaN         NaN
# 706222 2022-06-27   14:11:00  ...  DEG C    F01   NaN      NaN         NaN
# 706223 2022-06-27   15:08:00  ...  DEG C    F01   NaN      NaN         NaN
# 706224 2022-06-27   13:39:00  ...  DEG C    F01   NaN      NaN         NaN
#
#        BiasPC Details  Latitude Longitude  TierLevel
# 778       NaN     NaN  39.44149 -76.02599         T3
# 779       NaN     NaN  39.54794 -76.08481         T3
# 780       NaN     NaN  39.44149 -76.02599         T3
# 781       NaN     NaN  39.54794 -76.08481         T3
# 782       NaN     NaN  39.44149 -76.02599         T3
# ...       ...     ...       ...       ...        ...
# 706220    NaN     NaN  36.99570 -76.02048         T3
# 706221    NaN     NaN  36.99570 -76.02048         T3
# 706222    NaN     NaN  36.94737 -76.03494         T3
# 706223    NaN     NaN  36.99542 -76.16772         T3
# 706224    NaN     NaN  36.99570 -76.02048         T3
#
# [19935 rows x 30 columns]

# %%
# Combine 2021 and 2022 water quality data
combined_water_quality = pd.concat([water_quality_2021, water_quality_2022], ignore_index=True)

# Display the combined data
print(combined_water_quality)
# Out:
#       CBSeg2003   EventId  Cruise Program Project Agency Source Station  \
# 0        CB1TF   588081.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB1.1
# 1        CB1TF   588082.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# 2        CB1TF   588081.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB1.1
# 3        CB1TF   588082.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# 4        CB1TF   588060.0  BAY789    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# ...         ...       ...     ...     ...     ...    ...    ...     ...
# 40799    CB8PH   608326.0  BAY819    TWQM    MAIN  VADEQ    ODU   CB7.4
# 40800    CB8PH   608326.0  BAY819    TWQM    MAIN  VADEQ    ODU   CB7.4
# 40801    CB8PH   608335.0  BAY819    TWQM    MAIN  VADEQ    ODU  CB8.1E
# 40802    CB8PH   608332.0  BAY819    TWQM    MAIN  VADEQ    ODU   CB8.1
# 40803    CB8PH   608326.0  BAY819    TWQM    MAIN  VADEQ    ODU   CB7.4
#
#       SampleDate SampleTime  ...   Unit  Method  Lab  Problem PrecisionPC  \
# 0     2021-02-10   11:17:00  ...   UG/L    L01   CBL      NaN         NaN
# 1     2021-02-10   10:37:00  ...   UG/L    L01   CBL      NaN         NaN
# 2     2021-02-10   11:17:00  ...   UG/L    L01   CBL      NaN         NaN
# 3     2021-02-10   10:37:00  ...   UG/L    L01   CBL      NaN         NaN
# 4     2021-03-18   14:39:00  ...   UG/L    L01   CBL      NaN         NaN
# ...          ...        ...  ...    ...     ...  ...      ...         ...
# 40799 2022-06-27   13:39:00  ...  DEG C    F01   NaN      NaN         NaN
# 40800 2022-06-27   13:39:00  ...  DEG C    F01   NaN      NaN         NaN
# 40801 2022-06-27   14:11:00  ...  DEG C    F01   NaN      NaN         NaN
# 40802 2022-06-27   15:08:00  ...  DEG C    F01   NaN      NaN         NaN
# 40803 2022-06-27   13:39:00  ...  DEG C    F01   NaN      NaN         NaN
#
#       BiasPC Details  Latitude Longitude  TierLevel
# 0        NaN     NaN  39.54794 -76.08481         T3
# 1        NaN     NaN  39.44149 -76.02599         T3
# 2        NaN     NaN  39.54794 -76.08481         T3
# 3        NaN     NaN  39.44149 -76.02599         T3
# 4        NaN     NaN  39.44149 -76.02599         T3
# ...      ...     ...       ...       ...        ...
# 40799    NaN     NaN  36.99570 -76.02048         T3
# 40800    NaN     NaN  36.99570 -76.02048         T3
# 40801    NaN     NaN  36.94737 -76.03494         T3
# 40802    NaN     NaN  36.99542 -76.16772         T3
# 40803    NaN     NaN  36.99570 -76.02048         T3
#
# [40804 rows x 30 columns]

# %%
# Packages
# !pip install rasterio matplotlib

import rasterio
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.8.30)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading rasterio-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 75.6 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.4.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Landsat Imagery Band 1
#1
band1_file = '/content/drive/MyDrive/tiff/2022_04_B1.TIF'

with rasterio.open(band1_file) as src:
    band1 = src.read(1)  # Read the SWIR band

plt.imshow(band1, cmap='gray')
plt.colorbar()
plt.title('Landsat Band 1 (Coastal/Aerosol) - Visualization')
plt.show()

# %%
#Landsat Imagery Band 2
band2_file = '/content/drive/MyDrive/tiff/2021_12_B2.TIF'

with rasterio.open(band2_file) as src:
    band2 = src.read(1)  # Read the SWIR band

plt.imshow(band2, cmap='gray')
plt.colorbar()
plt.title('Landsat Band 2 (Blue) - Visualization')
plt.show()

# %%
#Landsat Imagery Band 3
#3
band3_file = '/content/drive/MyDrive/tiff/2022_07_B3.TIF'

with rasterio.open(band3_file) as src:
    band3 = src.read(1)  # Read the SWIR band

plt.imshow(band3, cmap='gray')
plt.colorbar()
plt.title('Landsat Band 3 (Green) - Visualization')
plt.show()

# %%
# Landsat Imagery Bands 4

band4_file = '/content/drive/MyDrive/tiff/2021_11_B4.TIF'

with rasterio.open(band4_file) as src:
    band4 = src.read(1)  # Read the Red band

# Plot the band
plt.imshow(band4, cmap='gray')
plt.colorbar()
plt.title('Landsat Band 4 (Red) - Visualization')
plt.show()

# %%
#Landsat Imagery Band 5
band5_file = '/content/drive/MyDrive/tiff/2022_12_B5.TIF'

with rasterio.open(band5_file) as src:
    band5 = src.read(1)  # Read the SWIR band

plt.imshow(band5, cmap='gray')
plt.colorbar()
plt.title('Landsat Band 5 (NIR) - Visualization')
plt.show()

# %%
#Landsat Imagery Band 6
band6_file = '/content/drive/MyDrive/tiff/2021_04_B6.TIF'

with rasterio.open(band6_file) as src:
    band6 = src.read(1)  # Read the SWIR band

plt.imshow(band6, cmap='gray')
plt.colorbar()
plt.title('Landsat Band 6 (SWIR 1) - Visualization')
plt.show()

# %%
#Landsat Imagery Band 7
band7_file = '/content/drive/MyDrive/tiff/2021_08_B7.TIF'

with rasterio.open(band7_file) as src:
    band7 = src.read(1)  # Read the SWIR 2 band

plt.imshow(band7, cmap='gray')
plt.colorbar()
plt.title('Landsat Band 7 (SWIR 2) - Visualization')
plt.show()

# %%
print(band4.shape)
print(band5.shape)
# Out:
# (7941, 7741)
# (7881, 7751)

# %%
# NDVI
from skimage.transform import resize

# Resize band5 (NIR) to match the shape of band4 (Red)
band5_resized = resize(band5, band4.shape, mode='constant', preserve_range=True)

# Now calculate NDVI with resized band5
NDVI = (band5_resized - band4) / (band5_resized + band4)

# Plot NDVI
plt.imshow(NDVI, cmap='YlGn')
plt.colorbar()
plt.title('NDVI (Normalized Difference Vegetation Index)')
plt.show()
# Out:
# <ipython-input-24-5b0c2acf9f47>:8: RuntimeWarning: invalid value encountered in divide
#   NDVI = (band5_resized - band4) / (band5_resized + band4)

# %%
import numpy as np
band3 = band3.astype(np.float32)
band5 = band5.astype(np.float32)

# %%
# NDWI
print(f"Shape of Green Band (Band 3): {band3.shape}")
print(f"Shape of NIR Band (Band 5): {band5.shape}")

from skimage.transform import resize

if band3.shape != band5.shape:
    band5 = resize(band5, band3.shape, mode='constant', preserve_range=True)

# Calculate NDWI
NDWI = (band3 - band5) / (band3 + band5)

# Plot NDWI
plt.imshow(NDWI, cmap='Blues')  # Use a blue colormap for water
plt.colorbar()
plt.title('NDWI (Normalized Difference Water Index)')
plt.show()
# Out:
# Shape of Green Band (Band 3): (7881, 7751)
# Shape of NIR Band (Band 5): (7881, 7751)
# <ipython-input-31-b3fda69073d9>:11: RuntimeWarning: invalid value encountered in divide
#   NDWI = (band3 - band5) / (band3 + band5)

# %%
# General plot of latitude vs longitude of combined_water_quality
import matplotlib.pyplot as plt

plt.scatter(combined_water_quality['Longitude'], combined_water_quality['Latitude'], alpha=0.5)
plt.title('Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Libraries
import geopandas as gpd
from shapely.geometry import Point

# Creating GeoDataFrame for combined_water_quality DataFrame
combined_water_quality['geometry'] = combined_water_quality.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)

# Converting DataFrame to a GeoDataFrame
combined_gdf = gpd.GeoDataFrame(combined_water_quality, geometry='geometry', crs="EPSG:4326")  # Assuming your coordinates are in WGS84 (latitude/longitude)

# Display the first few rows
print(combined_gdf.head())
# Out:
#   CBSeg2003   EventId  Cruise Program Project Agency Source Station  \
# 0    CB1TF   588081.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB1.1
# 1    CB1TF   588082.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# 2    CB1TF   588081.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB1.1
# 3    CB1TF   588082.0  BAY786    TWQM    MAIN  MDDNR  MDDNR   CB2.1
# 4    CB1TF   588060.0  BAY789    TWQM    MAIN  MDDNR  MDDNR   CB2.1
#
#   SampleDate SampleTime  ...  Method  Lab  Problem  PrecisionPC BiasPC  \
# 0 2021-02-10   11:17:00  ...    L01   CBL      NaN          NaN    NaN
# 1 2021-02-10   10:37:00  ...    L01   CBL      NaN          NaN    NaN
# 2 2021-02-10   11:17:00  ...    L01   CBL      NaN          NaN    NaN
# 3 2021-02-10   10:37:00  ...    L01   CBL      NaN          NaN    NaN
# 4 2021-03-18   14:39:00  ...    L01   CBL      NaN          NaN    NaN
#
#   Details  Latitude Longitude TierLevel                    geometry
# 0     NaN  39.54794 -76.08481        T3  POINT (-76.08481 39.54794)
# 1     NaN  39.44149 -76.02599        T3  POINT (-76.02599 39.44149)
# 2     NaN  39.54794 -76.08481        T3  POINT (-76.08481 39.54794)
# 3     NaN  39.44149 -76.02599        T3  POINT (-76.02599 39.44149)
# 4     NaN  39.44149 -76.02599        T3  POINT (-76.02599 39.44149)
#
# [5 rows x 31 columns]

# %%
# MODEL ... DUE 11/21
 # Normalization and z score transformation
 # Train data
 # model evaluation and fetaure importance

# %%
# Figures and Figures Code ... DUE
